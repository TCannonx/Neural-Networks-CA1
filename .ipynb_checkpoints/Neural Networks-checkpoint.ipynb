# %% [markdown]
# ## Extract image data from .tgz file

# %%
# import tarfile

# %%
# Access .tgz folder
# file = tarfile.open('EnglishImg.tgz')

# extract .tgz folder to 'data' folder
# file.extractall('./data')
  
# file.close()

# %% [markdown]
# ## Test Notebook

# %%
import tensorflow as tf

# %%
mnist = tf.keras.datasets.mnist

# %%
(x_train, y_train), (x_test, y_test) = mnist.load_data()

# %%
x_train = tf.keras.utils.normalize(x_train, axis=1)

# %%
x_test = tf.keras.utils.normalize(x_test, axis=1)

# %%
model = tf.keras.models.Sequential()

# %%
model.add(tf.keras.layers.Flatten(input_shape=(28, 28)))
# model.add(tf.keras.layers.Flatten(input_shape=(width, height)))

# %%
model.add(tf.keras.layers.Dense(128, activation='relu'))

# %%
model.add(tf.keras.layers.Dense(128, activation='relu'))

# %%
model.add(tf.keras.layers.Dense(10, activation='softmax'))

# %%
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %%
model.fit(x_train, y_train, epochs=3)
# Out:
# Epoch 1/3
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_1244\3380134371.py in <module>
# ----> 1 model.fit(x_train, y_train, epochs=3)
#
# ~\anaconda3\lib\site-packages\keras\utils\traceback_utils.py in error_handler(*args, **kwargs)
#      68             # To get the full stack trace, call:
#      69             # `tf.debugging.disable_traceback_filtering()`
# ---> 70             raise e.with_traceback(filtered_tb) from None
#      71         finally:
#      72             del filtered_tb
#
# ~\anaconda3\lib\site-packages\keras\engine\training.py in tf__train_function(iterator)
#      13                 try:
#      14                     do_return = True
# ---> 15                     retval_ = ag__.converted_call(ag__.ld(step_function), (ag__.ld(self), ag__.ld(iterator)), None, fscope)
#      16                 except:
#      17                     do_return = False
#
# ValueError: in user code:
#
#     File "C:\Users\tomca\anaconda3\lib\site-packages\keras\engine\training.py", line 1160, in train_function  *
#         return step_function(self, iterator)
#     File "C:\Users\tomca\anaconda3\lib\site-packages\keras\engine\training.py", line 1146, in step_function  **
#         outputs = model.distribute_strategy.run(run_step, args=(data,))
#     File "C:\Users\tomca\anaconda3\lib\site-packages\keras\engine\training.py", line 1135, in run_step  **
#         outputs = model.train_step(data)
#     File "C:\Users\tomca\anaconda3\lib\site-packages\keras\engine\training.py", line 993, in train_step
#         y_pred = self(x, training=True)
#     File "C:\Users\tomca\anaconda3\lib\site-packages\keras\utils\traceback_utils.py", line 70, in error_handler
#         raise e.with_traceback(filtered_tb) from None
#     File "C:\Users\tomca\anaconda3\lib\site-packages\keras\engine\input_spec.py", line 295, in assert_input_compatibility
#         raise ValueError(
#
#     ValueError: Input 0 of layer "sequential" is incompatible with the layer: expected shape=(None, 12, 648), found shape=(32, 28, 28)

# %%
model.save('digit.model')

# %%
model = tf.keras.models.load_model('digit.model')

# %%
loss, accuracy = model.evaluate(x_test, y_test)
# Out:
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0917 - accuracy: 0.9725

# %%
print(loss)
print(accuracy)
# Out:
# 0.09165820479393005
# 0.9725000262260437

# %%
import os
import re

# %%
import numpy as np

# %%
import cv2

# %%
folder_path = r'C:\Users\tomca\OneDrive\College Work\4th Year\Neural Networks\CA1\data\English\Img\GoodImg\Bmp'

# %%
data_dir = os.listdir(folder_path)

# %%
h_list = []
w_list = []

for sample in data_dir:
    
    sample_dir_path = folder_path + '/' + sample
    sample_dir = os.listdir(sample_dir_path)
    
    for img in sample_dir:
        current_char = re.findall('img\d+', img)[0]        
        text = current_char.replace('img', '')
        dig = int(text)
        current_dig = dig - 1
        
        image_dir = sample_dir_path + '/' + img
        
        if dig > 9:
            break
            
#         image = cv2.imread(image_dir)[:,:,0]
        image = cv2.imread(image_dir)
        image_width = image.shape[0]
        image_height = image.shape[1]
        
        w_list.append(image_width)
        h_list.append(image_height)
        
#         print('width: ', image_width)
#         print('height: ', image_height)
#         print('----------------------------------------------------------')
#         image = np.invert(np.array([image]))
#         image = tf.reshape(image, [28, 28])
#         prediction = model.predict(image)
#         print(f'This digit is probably a {np.argmax(prediction)}')

# %%
height = max(w_list)
width = min(w_list)

# %%
for sample in data_dir:
    
    sample_dir_path = folder_path + '/' + sample
    sample_dir = os.listdir(sample_dir_path)
    
    for img in sample_dir:
        current_char = re.findall('img\d+', img)[0]        
        text = current_char.replace('img', '')
        dig = int(text)
        current_dig = dig - 1
        
        image_dir = sample_dir_path + '/' + img
        
        if dig > 9:
            break
        else:
            try:
                image = cv2.imread(image_dir)[:,:,0]
                image = np.invert(np.array([image]))
    #             try:
                image = cv2.resize(image, (28, 28))
    #             image = cv2.imread(image_dir)[: :0]
#                 print(image)
                prediction = model.predict(image)
                print('actual digit: ', current_dig)
                print(f'Prediction: {np.argmax(prediction)}')
                print('--------------------------------------------')
#                 print(f'This digit is probably a {np.argmax(prediction)}')
                plt = imshow(image[0], cmap=plt.cm.binary)
                plt.show()
            except:
                continue
# Out:
# 1/1 [==============================] - 0s 41ms/step
# actual digit:  0
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 27ms/step
# actual digit:  0
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 20ms/step
# actual digit:  0
# Prediction: 3
# --------------------------------------------
# 1/1 [==============================] - 0s 21ms/step
# actual digit:  0
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 24ms/step
# actual digit:  0
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 23ms/step
# actual digit:  0
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 23ms/step
# actual digit:  0
# Prediction: 3
# --------------------------------------------
# 1/1 [==============================] - 0s 20ms/step
# actual digit:  0
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 25ms/step
# actual digit:  0
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 20ms/step
# actual digit:  0
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 20ms/step
# actual digit:  0
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 28ms/step
# actual digit:  0
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 20ms/step
# actual digit:  0
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 21ms/step
# actual digit:  0
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 21ms/step
# actual digit:  0
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 25ms/step
# actual digit:  0
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 19ms/step
# actual digit:  0
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 21ms/step
# actual digit:  0
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 23ms/step
# actual digit:  0
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 20ms/step
# actual digit:  0
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 22ms/step
# actual digit:  0
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 19ms/step
# actual digit:  0
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 24ms/step
# actual digit:  0
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 25ms/step
# actual digit:  0
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 27ms/step
# actual digit:  0
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 20ms/step
# actual digit:  0
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 21ms/step
# actual digit:  0
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 23ms/step
# actual digit:  0
# Prediction: 5
# --------------------------------------------
# 1/1 [==============================] - 0s 26ms/step
# actual digit:  0
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 22ms/step
# actual digit:  0
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 20ms/step
# actual digit:  0
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 19ms/step
# actual digit:  0
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 18ms/step
# actual digit:  0
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 25ms/step
# actual digit:  0
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 23ms/step
# actual digit:  0
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 22ms/step
# actual digit:  0
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 26ms/step
# actual digit:  0
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 20ms/step
# actual digit:  0
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 20ms/step
# actual digit:  0
# Prediction: 3
# --------------------------------------------
# 1/1 [==============================] - 0s 21ms/step
# actual digit:  0
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 23ms/step
# actual digit:  0
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 31ms/step
# actual digit:  0
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 20ms/step
# actual digit:  0
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 31ms/step
# actual digit:  0
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 35ms/step
# actual digit:  0
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 21ms/step
# actual digit:  0
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 23ms/step
# actual digit:  0
# Prediction: 5
# --------------------------------------------
# 1/1 [==============================] - 0s 22ms/step
# actual digit:  0
# Prediction: 3
# --------------------------------------------
# 1/1 [==============================] - 0s 21ms/step
# actual digit:  0
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 22ms/step
# actual digit:  0
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 22ms/step
# actual digit:  0
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 20ms/step
# actual digit:  0
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 20ms/step
# actual digit:  0
# Prediction: 3
# --------------------------------------------
# 1/1 [==============================] - 0s 20ms/step
# actual digit:  0
# Prediction: 6
# --------------------------------------------
# 1/1 [==============================] - 0s 24ms/step
# actual digit:  0
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 24ms/step
# actual digit:  0
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 23ms/step
# actual digit:  0
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 20ms/step
# actual digit:  0
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 28ms/step
# actual digit:  0
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 24ms/step
# actual digit:  0
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 21ms/step
# actual digit:  0
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 21ms/step
# actual digit:  0
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 25ms/step
# actual digit:  0
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 20ms/step
# actual digit:  0
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 20ms/step
# actual digit:  0
# Prediction: 3
# --------------------------------------------
# 1/1 [==============================] - 0s 21ms/step
# actual digit:  0
# Prediction: 5
# --------------------------------------------
# 1/1 [==============================] - 0s 22ms/step
# actual digit:  0
# Prediction: 3
# --------------------------------------------
# 1/1 [==============================] - 0s 23ms/step
# actual digit:  0
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 25ms/step
# actual digit:  0
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 24ms/step
# actual digit:  0
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 22ms/step
# actual digit:  0
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 18ms/step
# actual digit:  0
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 19ms/step
# actual digit:  0
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 19ms/step
# actual digit:  0
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 20ms/step
# actual digit:  0
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 41ms/step
# actual digit:  0
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 34ms/step
# actual digit:  0
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 33ms/step
# actual digit:  0
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 33ms/step
# actual digit:  0
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 20ms/step
# actual digit:  0
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 26ms/step
# actual digit:  0
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 33ms/step
# actual digit:  0
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 29ms/step
# actual digit:  0
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 23ms/step
# actual digit:  0
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 20ms/step
# actual digit:  0
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 19ms/step
# actual digit:  0
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 22ms/step
# actual digit:  0
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 20ms/step
# actual digit:  0
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 20ms/step
# actual digit:  0
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 26ms/step
# actual digit:  0
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 26ms/step
# actual digit:  0
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 20ms/step
# actual digit:  0
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 22ms/step
# actual digit:  0
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 20ms/step
# actual digit:  0
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 21ms/step
# actual digit:  0
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 23ms/step
# actual digit:  0
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 22ms/step
# actual digit:  0
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 21ms/step
# actual digit:  0
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 20ms/step
# actual digit:  0
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 27ms/step
# actual digit:  0
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 21ms/step
# actual digit:  0
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 25ms/step
# actual digit:  0
# Prediction: 5
# --------------------------------------------
# 1/1 [==============================] - 0s 20ms/step
# actual digit:  0
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 23ms/step
# actual digit:  0
# Prediction: 5
# --------------------------------------------
# 1/1 [==============================] - 0s 22ms/step
# actual digit:  0
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 37ms/step
# actual digit:  1
# Prediction: 5
# --------------------------------------------
# 1/1 [==============================] - 0s 23ms/step
# actual digit:  1
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 21ms/step
# actual digit:  1
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 20ms/step
# actual digit:  1
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 22ms/step
# actual digit:  1
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 21ms/step
# actual digit:  1
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 23ms/step
# actual digit:  1
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 21ms/step
# actual digit:  1
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 27ms/step
# actual digit:  1
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 24ms/step
# actual digit:  1
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 22ms/step
# actual digit:  1
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 25ms/step
# actual digit:  1
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 21ms/step
# actual digit:  1
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 21ms/step
# actual digit:  1
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 20ms/step
# actual digit:  1
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 21ms/step
# actual digit:  1
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 19ms/step
# actual digit:  1
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 27ms/step
# actual digit:  1
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 21ms/step
# actual digit:  1
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 19ms/step
# actual digit:  1
# Prediction: 3
# --------------------------------------------
# 1/1 [==============================] - 0s 21ms/step
# actual digit:  1
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 18ms/step
# actual digit:  1
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 19ms/step
# actual digit:  1
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 23ms/step
# actual digit:  1
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 23ms/step
# actual digit:  1
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 24ms/step
# actual digit:  1
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 21ms/step
# actual digit:  1
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 23ms/step
# actual digit:  1
# Prediction: 6
# --------------------------------------------
# 1/1 [==============================] - 0s 22ms/step
# actual digit:  1
# Prediction: 5
# --------------------------------------------
# 1/1 [==============================] - 0s 23ms/step
# actual digit:  1
# Prediction: 5
# --------------------------------------------
# 1/1 [==============================] - 0s 21ms/step
# actual digit:  1
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 23ms/step
# actual digit:  1
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 22ms/step
# actual digit:  1
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 24ms/step
# actual digit:  1
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 30ms/step
# actual digit:  1
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 23ms/step
# actual digit:  1
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 25ms/step
# actual digit:  1
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 23ms/step
# actual digit:  1
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 28ms/step
# actual digit:  1
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 23ms/step
# actual digit:  1
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 23ms/step
# actual digit:  1
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 22ms/step
# actual digit:  1
# Prediction: 5
# --------------------------------------------
# 1/1 [==============================] - 0s 27ms/step
# actual digit:  1
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 24ms/step
# actual digit:  1
# Prediction: 3
# --------------------------------------------
# 1/1 [==============================] - 0s 25ms/step
# actual digit:  1
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 20ms/step
# actual digit:  1
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 22ms/step
# actual digit:  1
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 23ms/step
# actual digit:  1
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 24ms/step
# actual digit:  1
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 25ms/step
# actual digit:  1
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 23ms/step
# actual digit:  1
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 23ms/step
# actual digit:  1
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 19ms/step
# actual digit:  1
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 21ms/step
# actual digit:  1
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 23ms/step
# actual digit:  1
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 26ms/step
# actual digit:  1
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 27ms/step
# actual digit:  1
# Prediction: 2
# --------------------------------------------
# 1/1 [==============================] - 0s 24ms/step
# actual digit:  1
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 22ms/step
# actual digit:  1
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 20ms/step
# actual digit:  1
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 20ms/step
# actual digit:  1
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 33ms/step
# actual digit:  1
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 37ms/step
# actual digit:  1
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 32ms/step
# actual digit:  1
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 31ms/step
# actual digit:  1
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 28ms/step
# actual digit:  1
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 30ms/step
# actual digit:  1
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 30ms/step
# actual digit:  1
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 23ms/step
# actual digit:  1
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 21ms/step
# actual digit:  1
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 22ms/step
# actual digit:  1
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 19ms/step
# actual digit:  1
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 21ms/step
# actual digit:  1
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 28ms/step
# actual digit:  1
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 28ms/step
# actual digit:  1
# Prediction: 3
# --------------------------------------------
# 1/1 [==============================] - 0s 26ms/step
# actual digit:  1
# Prediction: 3
# --------------------------------------------
# 1/1 [==============================] - 0s 21ms/step
# actual digit:  1
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 21ms/step
# actual digit:  1
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 23ms/step
# actual digit:  2
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 20ms/step
# actual digit:  2
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 23ms/step
# actual digit:  2
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 21ms/step
# actual digit:  2
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 23ms/step
# actual digit:  2
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 22ms/step
# actual digit:  2
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 23ms/step
# actual digit:  2
# Prediction: 5
# --------------------------------------------
# 1/1 [==============================] - 0s 22ms/step
# actual digit:  2
# Prediction: 5
# --------------------------------------------
# 1/1 [==============================] - 0s 25ms/step
# actual digit:  2
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 24ms/step
# actual digit:  2
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 23ms/step
# actual digit:  2
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 21ms/step
# actual digit:  2
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 21ms/step
# actual digit:  2
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 21ms/step
# actual digit:  2
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 24ms/step
# actual digit:  2
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 23ms/step
# actual digit:  2
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 23ms/step
# actual digit:  2
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 37ms/step
# actual digit:  2
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 38ms/step
# actual digit:  2
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 29ms/step
# actual digit:  2
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 31ms/step
# actual digit:  2
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 24ms/step
# actual digit:  2
# Prediction: 6
# --------------------------------------------
# 1/1 [==============================] - 0s 20ms/step
# actual digit:  2
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 22ms/step
# actual digit:  2
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 24ms/step
# actual digit:  2
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 23ms/step
# actual digit:  2
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 19ms/step
# actual digit:  2
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 23ms/step
# actual digit:  2
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 24ms/step
# actual digit:  2
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 26ms/step
# actual digit:  2
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 24ms/step
# actual digit:  2
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 34ms/step
# actual digit:  2
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 24ms/step
# actual digit:  2
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 24ms/step
# actual digit:  2
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 22ms/step
# actual digit:  2
# Prediction: 5
# --------------------------------------------
# 1/1 [==============================] - 0s 20ms/step
# actual digit:  2
# Prediction: 6
# --------------------------------------------
# 1/1 [==============================] - 0s 22ms/step
# actual digit:  2
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 24ms/step
# actual digit:  2
# Prediction: 5
# --------------------------------------------
# 1/1 [==============================] - 0s 20ms/step
# actual digit:  2
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 23ms/step
# actual digit:  2
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 21ms/step
# actual digit:  2
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 21ms/step
# actual digit:  2
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 22ms/step
# actual digit:  2
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 30ms/step
# actual digit:  2
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 25ms/step
# actual digit:  2
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 24ms/step
# actual digit:  2
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 25ms/step
# actual digit:  2
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 31ms/step
# actual digit:  2
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 25ms/step
# actual digit:  2
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 26ms/step
# actual digit:  2
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 26ms/step
# actual digit:  2
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 19ms/step
# actual digit:  2
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 21ms/step
# actual digit:  2
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 22ms/step
# actual digit:  2
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 21ms/step
# actual digit:  2
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 22ms/step
# actual digit:  2
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 23ms/step
# actual digit:  2
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 21ms/step
# actual digit:  2
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 32ms/step
# actual digit:  2
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 22ms/step
# actual digit:  2
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 25ms/step
# actual digit:  2
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 23ms/step
# actual digit:  2
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 24ms/step
# actual digit:  2
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 50ms/step
# actual digit:  2
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 42ms/step
# actual digit:  2
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 33ms/step
# actual digit:  2
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 24ms/step
# actual digit:  2
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 25ms/step
# actual digit:  2
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 21ms/step
# actual digit:  2
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 22ms/step
# actual digit:  2
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 25ms/step
# actual digit:  3
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 21ms/step
# actual digit:  3
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 27ms/step
# actual digit:  3
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 21ms/step
# actual digit:  3
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 23ms/step
# actual digit:  3
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 20ms/step
# actual digit:  3
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 24ms/step
# actual digit:  3
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 23ms/step
# actual digit:  3
# Prediction: 3
# --------------------------------------------
# 1/1 [==============================] - 0s 24ms/step
# actual digit:  3
# Prediction: 5
# --------------------------------------------
# 1/1 [==============================] - 0s 21ms/step
# actual digit:  3
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 24ms/step
# actual digit:  3
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 25ms/step
# actual digit:  3
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 23ms/step
# actual digit:  3
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 21ms/step
# actual digit:  3
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 23ms/step
# actual digit:  3
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 22ms/step
# actual digit:  3
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 26ms/step
# actual digit:  3
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 23ms/step
# actual digit:  3
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 20ms/step
# actual digit:  3
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 24ms/step
# actual digit:  3
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 19ms/step
# actual digit:  3
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 24ms/step
# actual digit:  3
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 20ms/step
# actual digit:  3
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 36ms/step
# actual digit:  3
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 35ms/step
# actual digit:  3
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 25ms/step
# actual digit:  3
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 32ms/step
# actual digit:  3
# Prediction: 5
# --------------------------------------------
# 1/1 [==============================] - 0s 20ms/step
# actual digit:  3
# Prediction: 6
# --------------------------------------------
# 1/1 [==============================] - 0s 22ms/step
# actual digit:  3
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 20ms/step
# actual digit:  3
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 21ms/step
# actual digit:  3
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 23ms/step
# actual digit:  3
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 20ms/step
# actual digit:  3
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 24ms/step
# actual digit:  3
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 23ms/step
# actual digit:  3
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 22ms/step
# actual digit:  3
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 25ms/step
# actual digit:  3
# Prediction: 5
# --------------------------------------------
# 1/1 [==============================] - 0s 20ms/step
# actual digit:  3
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 31ms/step
# actual digit:  3
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 21ms/step
# actual digit:  3
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 30ms/step
# actual digit:  3
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 20ms/step
# actual digit:  3
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 25ms/step
# actual digit:  3
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 24ms/step
# actual digit:  3
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 21ms/step
# actual digit:  3
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 21ms/step
# actual digit:  3
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 22ms/step
# actual digit:  3
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 20ms/step
# actual digit:  3
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 21ms/step
# actual digit:  3
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 22ms/step
# actual digit:  3
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 21ms/step
# actual digit:  4
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 23ms/step
# actual digit:  4
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 22ms/step
# actual digit:  4
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 20ms/step
# actual digit:  4
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 23ms/step
# actual digit:  4
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 24ms/step
# actual digit:  4
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 23ms/step
# actual digit:  4
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 22ms/step
# actual digit:  4
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 22ms/step
# actual digit:  4
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 22ms/step
# actual digit:  4
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 27ms/step
# actual digit:  4
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 27ms/step
# actual digit:  4
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 23ms/step
# actual digit:  4
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 23ms/step
# actual digit:  4
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 23ms/step
# actual digit:  4
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 22ms/step
# actual digit:  4
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 21ms/step
# actual digit:  4
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 21ms/step
# actual digit:  4
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 21ms/step
# actual digit:  4
# Prediction: 3
# --------------------------------------------
# 1/1 [==============================] - 0s 20ms/step
# actual digit:  4
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 21ms/step
# actual digit:  4
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 23ms/step
# actual digit:  4
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 27ms/step
# actual digit:  4
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 27ms/step
# actual digit:  4
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 31ms/step
# actual digit:  4
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 24ms/step
# actual digit:  4
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 25ms/step
# actual digit:  4
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 31ms/step
# actual digit:  4
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 37ms/step
# actual digit:  4
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 31ms/step
# actual digit:  4
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 32ms/step
# actual digit:  4
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 26ms/step
# actual digit:  4
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 25ms/step
# actual digit:  4
# Prediction: 6
# --------------------------------------------
# 1/1 [==============================] - 0s 25ms/step
# actual digit:  4
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 21ms/step
# actual digit:  4
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 23ms/step
# actual digit:  4
# Prediction: 3
# --------------------------------------------
# 1/1 [==============================] - 0s 24ms/step
# actual digit:  4
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 23ms/step
# actual digit:  4
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 23ms/step
# actual digit:  4
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 22ms/step
# actual digit:  4
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 22ms/step
# actual digit:  4
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 27ms/step
# actual digit:  4
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 22ms/step
# actual digit:  4
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 26ms/step
# actual digit:  4
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 22ms/step
# actual digit:  4
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 27ms/step
# actual digit:  4
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 22ms/step
# actual digit:  4
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 21ms/step
# actual digit:  5
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 22ms/step
# actual digit:  5
# Prediction: 3
# --------------------------------------------
# 1/1 [==============================] - 0s 26ms/step
# actual digit:  5
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 21ms/step
# actual digit:  5
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 20ms/step
# actual digit:  5
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 31ms/step
# actual digit:  5
# Prediction: 3
# --------------------------------------------
# 1/1 [==============================] - 0s 24ms/step
# actual digit:  5
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 27ms/step
# actual digit:  5
# Prediction: 2
# --------------------------------------------
# 1/1 [==============================] - 0s 23ms/step
# actual digit:  5
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 21ms/step
# actual digit:  5
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 22ms/step
# actual digit:  5
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 25ms/step
# actual digit:  5
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 22ms/step
# actual digit:  5
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 28ms/step
# actual digit:  5
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 23ms/step
# actual digit:  5
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 23ms/step
# actual digit:  5
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 22ms/step
# actual digit:  5
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 22ms/step
# actual digit:  5
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 21ms/step
# actual digit:  5
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 25ms/step
# actual digit:  5
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 23ms/step
# actual digit:  5
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 22ms/step
# actual digit:  5
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 20ms/step
# actual digit:  5
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 21ms/step
# actual digit:  5
# Prediction: 5
# --------------------------------------------
# 1/1 [==============================] - 0s 21ms/step
# actual digit:  5
# Prediction: 8
# --------------------------------------------
# ...
# 1/1 [==============================] - 0s 32ms/step
# actual digit:  6
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 33ms/step
# actual digit:  6
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 33ms/step
# actual digit:  6
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 30ms/step
# actual digit:  6
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 26ms/step
# actual digit:  6
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 28ms/step
# actual digit:  6
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 25ms/step
# actual digit:  6
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 24ms/step
# actual digit:  6
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 24ms/step
# actual digit:  6
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 28ms/step
# actual digit:  6
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 24ms/step
# actual digit:  6
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 24ms/step
# actual digit:  6
# Prediction: 3
# --------------------------------------------
# 1/1 [==============================] - 0s 25ms/step
# actual digit:  6
# Prediction: 3
# --------------------------------------------
# 1/1 [==============================] - 0s 26ms/step
# actual digit:  6
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 24ms/step
# actual digit:  6
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 25ms/step
# actual digit:  6
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 29ms/step
# actual digit:  6
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 24ms/step
# actual digit:  6
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 22ms/step
# actual digit:  6
# Prediction: 6
# --------------------------------------------
# 1/1 [==============================] - 0s 23ms/step
# actual digit:  6
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 24ms/step
# actual digit:  6
# Prediction: 3
# --------------------------------------------
# 1/1 [==============================] - 0s 22ms/step
# actual digit:  6
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 23ms/step
# actual digit:  6
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 21ms/step
# actual digit:  6
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 26ms/step
# actual digit:  6
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 22ms/step
# actual digit:  6
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 25ms/step
# actual digit:  6
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 21ms/step
# actual digit:  6
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 22ms/step
# actual digit:  6
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 25ms/step
# actual digit:  6
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 26ms/step
# actual digit:  6
# Prediction: 5
# --------------------------------------------
# 1/1 [==============================] - 0s 22ms/step
# actual digit:  6
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 22ms/step
# actual digit:  6
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 29ms/step
# actual digit:  6
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 27ms/step
# actual digit:  6
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 24ms/step
# actual digit:  6
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 26ms/step
# actual digit:  6
# Prediction: 3
# --------------------------------------------
# 1/1 [==============================] - 0s 23ms/step
# actual digit:  6
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 23ms/step
# actual digit:  6
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 24ms/step
# actual digit:  6
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 22ms/step
# actual digit:  6
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 24ms/step
# actual digit:  6
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 24ms/step
# actual digit:  6
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 23ms/step
# actual digit:  6
# Prediction: 3
# --------------------------------------------
# 1/1 [==============================] - 0s 33ms/step
# actual digit:  6
# Prediction: 6
# --------------------------------------------
# 1/1 [==============================] - 0s 35ms/step
# actual digit:  7
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 37ms/step
# actual digit:  7
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 36ms/step
# actual digit:  7
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 27ms/step
# actual digit:  7
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 26ms/step
# actual digit:  7
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 28ms/step
# actual digit:  7
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 28ms/step
# actual digit:  7
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 26ms/step
# actual digit:  7
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 26ms/step
# actual digit:  7
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 25ms/step
# actual digit:  7
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 24ms/step
# actual digit:  7
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 23ms/step
# actual digit:  7
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 24ms/step
# actual digit:  7
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 41ms/step
# actual digit:  7
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 30ms/step
# actual digit:  7
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 41ms/step
# actual digit:  7
# Prediction: 3
# --------------------------------------------
# 1/1 [==============================] - 0s 29ms/step
# actual digit:  7
# Prediction: 5
# --------------------------------------------
# 1/1 [==============================] - 0s 27ms/step
# actual digit:  7
# Prediction: 5
# --------------------------------------------
# 1/1 [==============================] - 0s 28ms/step
# actual digit:  7
# Prediction: 3
# --------------------------------------------
# 1/1 [==============================] - 0s 32ms/step
# actual digit:  7
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 27ms/step
# actual digit:  7
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 26ms/step
# actual digit:  7
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 24ms/step
# actual digit:  7
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 32ms/step
# actual digit:  7
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 25ms/step
# actual digit:  7
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 32ms/step
# actual digit:  7
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 25ms/step
# actual digit:  7
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 27ms/step
# actual digit:  7
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 23ms/step
# actual digit:  7
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 23ms/step
# actual digit:  7
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 24ms/step
# actual digit:  7
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 23ms/step
# actual digit:  7
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 27ms/step
# actual digit:  7
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 27ms/step
# actual digit:  7
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 29ms/step
# actual digit:  7
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 23ms/step
# actual digit:  7
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 23ms/step
# actual digit:  7
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 21ms/step
# actual digit:  7
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 24ms/step
# actual digit:  7
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 28ms/step
# actual digit:  7
# Prediction: 2
# --------------------------------------------
# 1/1 [==============================] - 0s 32ms/step
# actual digit:  7
# Prediction: 7
# --------------------------------------------
# 1/1 [==============================] - 0s 22ms/step
# actual digit:  7
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 23ms/step
# actual digit:  7
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 21ms/step
# actual digit:  7
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 21ms/step
# actual digit:  7
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 21ms/step
# actual digit:  7
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 24ms/step
# actual digit:  7
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 26ms/step
# actual digit:  7
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 21ms/step
# actual digit:  8
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 22ms/step
# actual digit:  8
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 22ms/step
# actual digit:  8
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 26ms/step
# actual digit:  8
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 24ms/step
# actual digit:  8
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 21ms/step
# actual digit:  8
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 27ms/step
# actual digit:  8
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 25ms/step
# actual digit:  8
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 21ms/step
# actual digit:  8
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 21ms/step
# actual digit:  8
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 22ms/step
# actual digit:  8
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 20ms/step
# actual digit:  8
# Prediction: 3
# --------------------------------------------
# 1/1 [==============================] - 0s 20ms/step
# actual digit:  8
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 19ms/step
# actual digit:  8
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 23ms/step
# actual digit:  8
# Prediction: 3
# --------------------------------------------
# 1/1 [==============================] - 0s 20ms/step
# actual digit:  8
# Prediction: 6
# --------------------------------------------
# 1/1 [==============================] - 0s 22ms/step
# actual digit:  8
# Prediction: 6
# --------------------------------------------
# 1/1 [==============================] - 0s 24ms/step
# actual digit:  8
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 26ms/step
# actual digit:  8
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 25ms/step
# actual digit:  8
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 22ms/step
# actual digit:  8
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 22ms/step
# actual digit:  8
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 22ms/step
# actual digit:  8
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 25ms/step
# actual digit:  8
# Prediction: 6
# --------------------------------------------
# 1/1 [==============================] - 0s 20ms/step
# actual digit:  8
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 24ms/step
# actual digit:  8
# Prediction: 3
# --------------------------------------------
# 1/1 [==============================] - 0s 22ms/step
# actual digit:  8
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 21ms/step
# actual digit:  8
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 24ms/step
# actual digit:  8
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 24ms/step
# actual digit:  8
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 20ms/step
# actual digit:  8
# Prediction: 8
# --------------------------------------------
# 1/1 [==============================] - 0s 21ms/step
# actual digit:  8
# Prediction: 8
# --------------------------------------------

# %%
test = 'img004'

# %%
def func(text):
    text = text.replace('img', '')
    dig = int(text)
    current_dig = dig - 1
    return current_dig

# %%
func(test)
# Out:
# 3
